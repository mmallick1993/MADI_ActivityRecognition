# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from os import chdir
from glob import glob
import pandas as pd
import glob
import os

from sklearn.preprocessing import MinMaxScaler    
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score

# %%
#path= 'C:/Users/mmall/OneDrive/Desktop/##WS 2021/MADI_4.0/ardata/1.csv'
path=r'C:/Users/antonebert/Desktop/WS2021 Programing/MADI/Activity Recognition from Single Chest-Mounted Accelerometer/2.csv'
df = pd.read_csv(path)
columns=['Sequence','x','y','z','label']
df.columns=columns
#df=df.drop(columns=['Sequence'])
print(df.shape)
df=df[df["label"] != 0] #data cleaning: Leaving out unlabeled data || (3719, 4)
print(df.shape)
# Out:
# (138000, 5)
# (137730, 5)

# %% [markdown]
# # Note: Need to perform subjectwise analysis and training

# %%
def subject_plot(sub,df):
    classes= list(set(df['label']))
    print(classes)
    for cls in classes:
        df_cls = df[df['label']==cls]            
        t= df_cls.Sequence
        x= df_cls.x
        y= df_cls.y
        z= df_cls.z
        #plt.subplot(4,2,cls)
        plt.plot(t,x,'r',label='x')
        plt.plot(t,y,'g',label='y')
        plt.plot(t,z,'b', label='z')
        plt.legend()
        fig_name='class_'+str(cls)+'_sub_'+str(sub)+'.png'
        print(fig_name)
        plt.title(fig_name)
        # plt.savefig(fig_name,bbox_inches='tight')
        plt.show()
        
    return None

# %%
from os import chdir
from glob import glob
import pandas as pd
import glob
import os

path = r'C:/Users/antonebert/Desktop/WS2021 Programing/MADI/Activity Recognition from Single Chest-Mounted Accelerometer/'

def subject_data():
    for sub in range(1,16):
        path_sub = path + str(sub) + '.csv'
        df=pd.read_csv(path_sub, header=None) 
        columns=['Sequence','x','y','z','label']
        df.columns=columns
        df=df[df["label"] != 0]
        subject_plot(sub,df)
    return None

# %%
subject_data()
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_1.png
# class_2_sub_1.png
# class_3_sub_1.png
# class_4_sub_1.png
# class_5_sub_1.png
# class_6_sub_1.png
# class_7_sub_1.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_2.png
# class_2_sub_2.png
# class_3_sub_2.png
# class_4_sub_2.png
# class_5_sub_2.png
# class_6_sub_2.png
# class_7_sub_2.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_3.png
# class_2_sub_3.png
# class_3_sub_3.png
# class_4_sub_3.png
# class_5_sub_3.png
# class_6_sub_3.png
# class_7_sub_3.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_4.png
# class_2_sub_4.png
# class_3_sub_4.png
# class_4_sub_4.png
# class_5_sub_4.png
# class_6_sub_4.png
# class_7_sub_4.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_5.png
# class_2_sub_5.png
# class_3_sub_5.png
# class_4_sub_5.png
# class_5_sub_5.png
# class_6_sub_5.png
# class_7_sub_5.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_6.png
# class_2_sub_6.png
# class_3_sub_6.png
# class_4_sub_6.png
# class_5_sub_6.png
# class_6_sub_6.png
# class_7_sub_6.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_7.png
# class_2_sub_7.png
# class_3_sub_7.png
# class_4_sub_7.png
# class_5_sub_7.png
# class_6_sub_7.png
# class_7_sub_7.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_8.png
# class_2_sub_8.png
# class_3_sub_8.png
# class_4_sub_8.png
# class_5_sub_8.png
# class_6_sub_8.png
# class_7_sub_8.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_9.png
# class_2_sub_9.png
# class_3_sub_9.png
# class_4_sub_9.png
# class_5_sub_9.png
# class_6_sub_9.png
# class_7_sub_9.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_10.png
# class_2_sub_10.png
# class_3_sub_10.png
# class_4_sub_10.png
# class_5_sub_10.png
# class_6_sub_10.png
# class_7_sub_10.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_11.png
# class_2_sub_11.png
# class_3_sub_11.png
# class_4_sub_11.png
# class_5_sub_11.png
# class_6_sub_11.png
# class_7_sub_11.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_12.png
# class_2_sub_12.png
# class_3_sub_12.png
# class_4_sub_12.png
# class_5_sub_12.png
# class_6_sub_12.png
# class_7_sub_12.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_13.png
# class_2_sub_13.png
# class_3_sub_13.png
# class_4_sub_13.png
# class_5_sub_13.png
# class_6_sub_13.png
# class_7_sub_13.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_14.png
# class_2_sub_14.png
# class_3_sub_14.png
# class_4_sub_14.png
# class_5_sub_14.png
# class_6_sub_14.png
# class_7_sub_14.png
# [1, 2, 3, 4, 5, 6, 7]
# class_1_sub_15.png
# class_2_sub_15.png
# class_3_sub_15.png
# class_4_sub_15.png
# class_5_sub_15.png
# class_6_sub_15.png
# class_7_sub_15.png

# %%
# Out:
# basic_1.png
# basic_2.png
# basic_3.png
# basic_4.png
# basic_5.png
# basic_6.png
# basic_7.png

# %%
#Data Cleaning

df_clean =  pd.DataFrame()
for cls in classes:
    df_cls = df[df['label']==cls]
    print('df_class', df_cls.shape)
    for col in ['x', 'y', 'z']:
        col_mean = np.mean(df_cls[col])
        col_std = np.std(df_cls[col])
        mask = (df_cls[col] < col_mean+2*col_std)  & (df_cls[col] > col_mean-2*col_std)
        df_cls = df_cls.loc[mask]
    print('df_clean_class',df_cls.shape)
    pd.concat([df_clean,df_cls], ignore_index=True, sort=False)
            
    t= df_cls.Sequence
    x= df_cls.x
    y= df_cls.y
    z= df_cls.z
    plt.plot(t,x,'r',label='x')
    plt.plot(t,y,'g',label='y')
    plt.plot(t,z,'b', label='z')
    plt.legend()
    plt.title(cls)
    plt.show()
# Out:
# df_class (608667, 5)
# df_clean_class (548020, 5)
# df_class (47878, 5)
# df_clean_class (42455, 5)
# df_class (216737, 5)
# df_clean_class (194366, 5)
# df_class (357064, 5)
# df_clean_class (311507, 5)
# df_class (51498, 5)
# df_clean_class (46897, 5)
# df_class (47770, 5)
# df_clean_class (45273, 5)
# df_class (593563, 5)
# df_clean_class (545397, 5)

# %%
df1=df[df['label']==1]
df2=df[df['label']==2]
df3=df[df['label']==3]
df4=df[df['label']==4]
df5=df[df['label']==5]
df6=df[df['label']==6]
df7=df[df['label']==7]

# %%
t=df1.Sequence
x= df1.x
y=df1.y
z=df1.z
plt.plot(t,x,'r',label='x')
plt.plot(t,y,'g',label='y')
plt.plot(t,z,'b', label='z')
plt.legend()
#print(t[10])

# %%
print(df2.shape)
t=df2.Sequence
x= df2.x
y=df2.y
z=df2.z
plt.plot(t,x,'r',label='x')
plt.plot(t,y,'g',label='y')
plt.plot(t,z,'b', label='z')
plt.legend()
#print(t[10])
# Out:
# (3485, 5)

# %%
print(df2.describe())
# Out:
#            Sequence            x            y            z   label
# count   3485.000000  3485.000000  3485.000000  3485.000000  3485.0
# mean   45782.000000  1809.970158  2341.155811  2002.865710     2.0
# std     1006.177171    10.531715     6.350967     8.374027     0.0
# min    44040.000000  1789.000000  2306.000000  1954.000000     2.0
# 25%    44911.000000  1806.000000  2338.000000  2000.000000     2.0
# 50%    45782.000000  1809.000000  2340.000000  2002.000000     2.0
# 75%    46653.000000  1811.000000  2343.000000  2005.000000     2.0
# max    47524.000000  1926.000000  2398.000000  2076.000000     2.0

# %%
x_mean=np.mean(df2['x'])
x_std=np.std(df2['x'])
mask=(df2['x'] < x_mean+2*x_std)  & (df2['x'] > x_mean-2*x_std)
df2=df2.loc[mask]

y_mean=np.mean(df2['y'])
y_std=np.std(df2['y'])
mask=(df2['y'] < y_mean+2*y_std)  & (df2['y'] > y_mean-2*y_std)
df2=df2.loc[mask]

z_mean=np.mean(df2['z'])
z_std=np.std(df2['z'])
mask=(df2['z'] < z_mean+2*z_std)  & (df2['z'] > z_mean-2*z_std)
df2=df2.loc[mask]

# %%
print(df2.shape)
t=df2.Sequence
x= df2.x
y=df2.y
z=df2.z
plt.plot(t,x,'r',label='x')
plt.plot(t,y,'g',label='y')
plt.plot(t,z,'b', label='z')
plt.legend()
# Out:
# (3117, 5)

# %%
mask = (df['date'] > '2000-6-1') & (df['date'] <= '2000-6-10')
print(df.loc[mask])

# %% [markdown]
# ## Data are separated by participant
# Each file contains the following information
# sequential number, x acceleration, y acceleration, z acceleration, label
# Labels are codified by numbers
#
# 1: Working at Computer
#
# 2: Standing Up, Walking and Going updown stairs
#
# 3: Standing
#
# 4: Walking
#
# 5: Going UpDown Stairs
#
# 6: Walking and Talking with Someone
#
# 7: Talking while Standing

# %% [markdown]
# #### Class Distribution

# %%
sns.countplot(x = 'label', data=df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df.head(-5)
# Out:
#            x     y     z  label
# 0       1667  2072  2047      1
# 1       1611  1957  1906      1
# 2       1601  1939  1831      1
# 3       1643  1965  1879      1
# 4       1604  1959  1921      1
# ...      ...   ...   ...    ...
# 162489  1931  2383  2076      7
# 162490  1927  2383  2079      7
# 162491  1931  2388  2076      7
# 162492  1932  2383  2072      7
# 162493  1931  2386  2073      7
#
# [162494 rows x 4 columns]

# %%
#Create input output data
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
#Over Sample
ros= RandomOverSampler(random_state=0)
ros.fit(X,y)
X_resampled, y_resampled = ros.fit_sample(X,y)
df_resample = pd.concat([X_resampled,y_resampled], axis = 1)
print(df_resample.head)
sns.countplot(x = 'label', data=df_resample)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-c36e52dc3228> in <module>
#       1 #Over Sample
# ----> 2 ros= RandomOverSampler(random_state=0)
#       3 ros.fit(X,y)
#       4 X_resampled, y_resampled = ros.fit_sample(X,y)
#       5 df_resample = pd.concat([X_resampled,y_resampled], axis = 1)
#
# NameError: name 'RandomOverSampler' is not defined

# %%
# Split into train+val (80%) and test(20%)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=69) 

# implementing train-test-split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.33, random_state=66)

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
# random forest model creation
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
# predictions
rfc_predict = rfc.predict(X_test)

# %%
rfc_cv_score = cross_val_score(rfc, X, y, cv=7)

# %%
print("=== Confusion Matrix ===")
cm=confusion_matrix(y_test, rfc_predict)
print(cm)
print('\n')
cm=(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis])
print(cm)
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())

# %%
print("=== Confusion Matrix ===")
confusion_matrix=confusion_matrix(y_test, rfc_predict)
confusion_matrix=(confusion_matrix.astype('float') / confusion_matrix.sum(axis=1)[:, np.newaxis])
print(confusion_matrix)
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())

# %% [markdown]
# Data are separated by participant
# Each file contains the following information sequential number, x acceleration, y acceleration, z acceleration, label Labels are codified by numbers
#
# 1: Working at Computer
#
# 2: Standing Up, Walking and Going updown stairs
#
# 3: Standing
#
# 4: Walking
#
# 5: Going UpDown Stairs
#
# 6: Walking and Talking with Someone
#
# 7: Talking while Standing

# %%
confusion_matrix

# %%
np.round(confusion_matrix,2)
